# %% [markdown]
# # Test page

# %%
# %pip install https://files.pythonhosted.org/packages/7a/b9/e29436bf66898f57e4aabc37f8376f95387e74ce8c611092a251c946c710/ipyquizjb-0.3.9.dev0-py3-none-any.whl
from ipyquizjb.questions import display_questions, display_package

# display_questions([{
#     "type": "TEXT",
#     "body": "Si consideri il segnale a tempo continuo $x(t)$ della seguente figura, dove la griglia \\'e unitaria.\r\n\r\n<script type=\"text/tikz\">\\begin{tikzpicture}\r\n            \\draw[thin, gray!40] (-4,-1) grid (4,2);\r\n            \\draw[-latex] (-4,0) -- (4,0) node[anchor=north west] {$t$} ;\r\n            \\draw[-latex] (0,-1) -- (0,2) node[anchor=north west, color=blue] {$x(t)$};\r\n            \\draw[blue, very thick] (-4,0) -- (-2,0) -- (-1,1) -- (1,1) -- (2,0) -- (4,0);\r\n        \\end{tikzpicture}</script>\r\n\r\nCalcolare la trasformata di Fourier $X(f)$ (suggerimento: si pensi a come ottenere questo segnale come opportuna convoluzione di segnali conosciuti).",
#     "notes": ["Si consideri il segnale a tempo continuo $x(t)$ della seguente figura, dove la griglia \\'e unitaria.\r\n\r\n<script type=\"text/tikz\">\\begin{tikzpicture}\r\n            \\draw[thin, gray!40] (-4,-1) grid (4,2);\r\n            \\draw[-latex] (-4,0) -- (4,0) node[anchor=north west] {$t$} ;\r\n            \\draw[-latex] (0,-1) -- (0,2) node[anchor=north west, color=blue] {$x(t)$};\r\n            \\draw[blue, very thick] (-4,0) -- (-2,0) -- (-1,1) -- (1,1) -- (2,0) -- (4,0);\r\n        \\end{tikzpicture}</script>\r\n\r\nCalcolare la trasformata di Fourier $X(f)$ (suggerimento: si pensi a come ottenere questo segnale come opportuna convoluzione di segnali conosciuti)."]
# }])

display_package({
    "questions": [
        {
            "type": "MULTIPLE_CHOICE",
            "body": "What is the derivative of \\( \\sin(x) \\)?",
            "answers": [
                "\\( -\\cos(x) \\).",
                "\\( \\tan(x) \\).",
                "\\( \\cos(x) \\)."
            ],  # Alternatives
            "answer": ["\\( \\cos(x) \\)."],  # Correct answers, one or more
            "when": "initial", # Optional. "initial" if this should always be displayed on first load, "retry" if it should be part of the pool of questions loaded when trying again with new questions.
        },
        {
    "type": "TEXT",
    "body": "Si consideri il segnale a tempo continuo $x(t)$ della seguente figura, dove la griglia \\'e unitaria.\r\n\r\n<script type=\"text/tikz\">\\begin{tikzpicture}\r\n            \\draw[thin, gray!40] (-4,-1) grid (4,2);\r\n            \\draw[-latex] (-4,0) -- (4,0) node[anchor=north west] {$t$} ;\r\n            \\draw[-latex] (0,-1) -- (0,2) node[anchor=north west, color=blue] {$x(t)$};\r\n            \\draw[blue, very thick] (-4,0) -- (-2,0) -- (-1,1) -- (1,1) -- (2,0) -- (4,0);\r\n        \\end{tikzpicture}</script>\r\n\r\nCalcolare la trasformata di Fourier $X(f)$ (suggerimento: si pensi a come ottenere questo segnale come opportuna convoluzione di segnali conosciuti).",
    "notes": ["Si consideri il segnale a tempo continuo $x(t)$ della seguente figura, dove la griglia \\'e unitaria.\r\n\r\n<script type=\"text/tikz\">\\begin{tikzpicture}\r\n            \\draw[thin, gray!40] (-4,-1) grid (4,2);\r\n            \\draw[-latex] (-4,0) -- (4,0) node[anchor=north west] {$t$} ;\r\n            \\draw[-latex] (0,-1) -- (0,2) node[anchor=north west, color=blue] {$x(t)$};\r\n            \\draw[blue, very thick] (-4,0) -- (-2,0) -- (-1,1) -- (1,1) -- (2,0) -- (4,0);\r\n        \\end{tikzpicture}</script>\r\n\r\nCalcolare la trasformata di Fourier $X(f)$ (suggerimento: si pensi a come ottenere questo segnale come opportuna convoluzione di segnali conosciuti)."],
    "when": "retry"
},
    ]
})
# Out:
# ...
#   Attempting uninstall: ipyquizjb
#     Found existing installation: ipyquizjb 0.3.8
#     Uninstalling ipyquizjb-0.3.8:
#       Successfully uninstalled ipyquizjb-0.3.8
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# <script>
#                  function versionAgnosticTypeset(element) {
#                     if (MathJax.version.startsWith("3")) {
#                         if (element) {
#                             MathJax.typeset(element)
#                         } else {
#                             MathJax.typeset()
#                         }
#                     } else {
#                         if (element) {
#                             MathJax.Hub.Queue(['Typeset', MathJax.Hub, element]);
#                         } else {
#                             MathJax.Hub.Queue(['Typeset', MathJax.Hub]);
# ...
