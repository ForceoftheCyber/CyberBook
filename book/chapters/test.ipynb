# %% [markdown]
# # Test page

# %%
# %pip install https://files.pythonhosted.org/packages/6e/3b/0727fdb92309f7d1f43cd4834d55d32a40cf5c91676391052eb5670377cc/ipyquizjb-0.3.7.dev10-py3-none-any.whl
from ipyquizjb import display_questions

display_questions([
    {
      "type": "MULTIPLE_CHOICE",
      "body": "What is the derivative of \\( \\sin(x) \\)?",
      "answers": [
        "\\( {-\\cos(x)} \\).",
        "\\( {\\tan(x)} \\).",
        "\\( {\\cos(x)} \\)."
      ],
      "answer": ["\\( {\\cos(x)} \\)."],
      "notes": ["The derivative of \\( \\sin(x) \\) is \\( \\cos(x) \\)."]
    },
    {
      "type": "NUMERIC",
      "body": "What's the derivative of z (z'), with respect to x, of z = 4y+x?",
      "answer": "1",
      "notes": []
    }])

display_questions([
    {
      "type": "MULTIPLE_CHOICE",
      "body": "What is the derivative of \\( \\sin(x) \\)?",
      "answers": [
        "\\( {-\\cos(x)} \\).",
        "\\( {\\tan(x)} \\).",
        "\\( {\\cos(x)} \\)."
      ],
      "answer": ["\\( {\\cos(x)} \\)."],
      "notes": ["The derivative of \\( \\sin(x) \\) is \\( \\cos(x) \\)."]
    },
    {
      "type": "NUMERIC",
      "body": "What's the derivative of z (z'), with respect to x, of z = 4y+x?",
      "answer": "1",
      "notes": []
    }])
