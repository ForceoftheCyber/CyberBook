# %%
# %pip install ipyquizjb
from ipyquizjb.questions import display_package
# Out:
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Requirement already satisfied: ipyquizjb in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (0.3.8)
# Requirement already satisfied: ipython in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipyquizjb) (9.1.0)
# Requirement already satisfied: ipywidgets in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipyquizjb) (8.1.5)
# Requirement already satisfied: requests in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipyquizjb) (2.32.3)
# Requirement already satisfied: colorama in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (0.4.6)
# Requirement already satisfied: decorator in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (3.0.50)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (2.19.1)
# Requirement already satisfied: stack_data in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipython->ipyquizjb) (5.14.3)
# Requirement already satisfied: comm>=0.1.3 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipywidgets->ipyquizjb) (0.2.2)
# Requirement already satisfied: widgetsnbextension~=4.0.12 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipywidgets->ipyquizjb) (4.0.13)
# Requirement already satisfied: jupyterlab-widgets~=3.0.12 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from ipywidgets->ipyquizjb) (3.0.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from requests->ipyquizjb) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from requests->ipyquizjb) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from requests->ipyquizjb) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from requests->ipyquizjb) (2025.1.31)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from jedi>=0.16->ipython->ipyquizjb) (0.8.4)
# Requirement already satisfied: wcwidth in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->ipyquizjb) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from stack_data->ipython->ipyquizjb) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from stack_data->ipython->ipyquizjb) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\synne\documents\cyberbook\.venv\lib\site-packages (from stack_data->ipython->ipyquizjb) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Linearization & Stability
#
# The maglev system is most easily controlled by first applying the following change of variables on the input:
#
# $$
# 		u_x := I_p-I_n, \quad u_z := I_p + I_n.
# $$
#
# By doing this it is possible to decouple the control of $x$ and $z$, simplifying our analysis.
# With this change of variables, we may linearize the above model with an appopriate set of parameters, giving us the input-to-state transfer functions:
#
# $$
#   G_x(s) = \frac{a_0s^2+a_1}{s^4+b_1s^2-b_2}, \quad G_z(s) = \frac{a_2}{s^2 + b_3},
# $$
#
# for some parameters $a_i > 0$ and $b_i > 0$.
# Assuming that we only measure the magnetic field in the $x$ direction, we have that the input-to-ouptut transfer function is given by:
#
# $$
#   G(s) = cG_x(s), \quad c > 0.
# $$

# %% [markdown]
# ## Quiz

# %%
display_package({
        "questions": [
            {
                "type": "MULTIPLE_CHOICE",
                "body": "Is the system stable?",
                "answers": [
                    "Yes",
                    "No",
                ],
                "answer": ["No"],
            },
            {
                "type": "MULTIPLE_CHOICE",
                "body": "Is the system controllable?",
                "answers": [
                    "Yes",
                    "No",
                ],
                "answer": ["No"],
            },
            {
                "type": "MULTIPLE_CHOICE",
                "body": "Is the system observable?",
                "answers": [
                    "Yes",
                    "No",
                ],
                "answer": ["No"],
            },
            {
                "type": "MULTIPLE_CHOICE",
                "body": "Is it okay to break our system up like this?",
                "answers": [
                    "Yes",
                    "No",
                ],
                "answer": ["Yes"],
            },
        ],
    }
)
# Out:
# <script>
# // Makes buttons with rendered math clickable by
# // listening for click on the math and then
# // resending a click to the actual button
# function make_latex_buttons_clickable() {
#     for (element of document.querySelectorAll("button mjx-container")) {
#         if (element.hasAttribute('clickable-math-listener')) {
#             // Skip if listener is already attached
#             continue;
#         }
#         element.addEventListener("click", (e) => {
#             // Find the actual button and click it
#             e.stopPropagation();
#             var parent = e.target.parentElement
#             while (!parent.classList.contains("jupyter-button")) {
#                 parent = parent.parentElement;
#             }
#             parent.click();
#         });
#         element.setAttribute("clickable-math-listener", "");
#     };
# }
#
# // Used on every rerender
# function typesetAll() {
#     console.log("Rerender typeset");
#     MathJax.typeset([...document.getElementsByClassName("ipyquizjb-render-math")]);
#     make_latex_buttons_clickable();
# }
#
# typesetAll();
# </script>
# VBox(children=(Output(), Output()), _dom_classes=('ipyquizjb-render-math',))
# <script>typesetAll();</script>
